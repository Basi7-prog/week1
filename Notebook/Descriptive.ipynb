# %%
import sys 
sys.path.append(r'C:\Users\Baslael\Documents\Kifiya\week1\script')
from Stock_Analysis import Stocks

# %%
snt=Stocks.read_sentiment()
snt
# Out:
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %%
[wht,publishers_names]=Stocks.active_publisher(snt)
wht
# Out:
# C:\Users\Baslael\Documents\Kifiya\week1\script\Stock_Analysis.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snt2['date']=Stocks.change_to_date(snt2['date'])
#                    articles published  in_percent
# Paul Quintaro                  228373   16.227418
# Lisa Levin                     186979   13.286100
# Benzinga Newsdesk              150484   10.692888
# Charles Gross                   96732    6.873451
# Monica Gerson                   82380    5.853646
# Eddie Staley                    57254    4.068277
# Hal Lindon                      49047    3.485115
# ETF Professor                   28489    2.024333
# Juan Lopez                      28438    2.020709
# Benzinga Staff                  28114    1.997686
# ...

# %%
publishers_names
# Out:
#          Unnamed: 0                                           headline  \
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# 7                 7  Agilent Technologies shares are trading higher...
# 9                 9         10 Biggest Price Target Changes For Friday
# ...             ...                                                ...
# 1407320     1413841  China Zenix Announces Open Market Stock Purcha...
# 1407321     1413842  China Zenix Auto International Awarded Wheel S...
# 1407322     1413843  China Zenix Auto International Selected as Exc...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %%
Stocks.index_edit(publishers_names,"date")
# Out:
# C:\Users\Baslael\Documents\Kifiya\week1\script\Stock_Analysis.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col]=Stocks.change_to_date(data[col])
#                      Unnamed: 0  \
# date
# 2020-05-26 08:30:07           2
# 2020-05-22 16:45:06           3
# 2020-05-22 15:38:59           4
# 2020-05-22 13:07:04           7
# 2020-05-22 12:06:17           9
# ...                         ...
# 2011-12-30 00:00:00     1413841
# 2011-11-28 00:00:00     1413842
# 2011-11-21 00:00:00     1413843
# 2011-08-29 00:00:00     1413844
# 2011-05-12 00:00:00     1413848
#
#                                                               headline  \
# date
# 2020-05-26 08:30:07                      71 Biggest Movers From Friday
# ...

# %%
Stocks.plot_news_frequency(publishers_names,'D')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

tots=publishers_names.loc[((publishers_names.index.month==2))&(publishers_names.index.year==2020)]
# Stocks.plot_news_frequency(tots,'D')
no_published_date=tots.index.value_counts()
sorted_df=no_published_date.sort_index()
# plt.yticks(ticks=tots.index, labels=tots.index.strftime('%A'))
sorted_df.resample('D').sum().plot(figsize=(40,20), kind='line')
plt.xticks(ticks=sorted_df.index, labels=sorted_df.index.strftime('%A'))
# Out:
# ([<matplotlib.axis.XTick at 0x1b88f58b5b0>,
# ...
#   ...],
#  [Text(18293, 0, 'Saturday'),
#   Text(18294, 0, 'Sunday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
#   Text(18295, 0, 'Monday'),
# ...

# %%
#Sentiment analysis
# import pandas as pd
# polarity=[]
# subjectivity=[]
# for index, row in publishers_names.iterrows():
#     polarity.append(TextBlob(row["headline"]).sentiment.polarity)
#     subjectivity.append(TextBlob(row["headline"]).sentiment.subjectivity)
    
# publishers_names["polarity"]=polarity
# publishers_names["subjectivity"]=subjectivity
Stocks.sentiment_analysis(publishers_names)
publishers_names
# Out:
# C:\Users\Baslael\Documents\Kifiya\week1\script\Stock_Analysis.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["polarity"]=polarity
# C:\Users\Baslael\Documents\Kifiya\week1\script\Stock_Analysis.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["subjectivity"]=subjectivity
#                      Unnamed: 0  \
# date
# 2020-05-26 08:30:07           2
# 2020-05-22 16:45:06           3
# 2020-05-22 15:38:59           4
# 2020-05-22 13:07:04           7
# ...

# %%
publishers_names2=publishers_names[['polarity','subjectivity']].resample('D').mean()
publishers_names2.dropna()
# Out:
#             polarity  subjectivity
# date
# 2009-07-27  0.041490      0.178902
# 2009-08-06  0.015449      0.055233
# 2009-08-07  0.073605      0.156503
# 2009-08-08 -0.028571      0.142857
# 2009-08-09  0.134854      0.349593
# ...              ...           ...
# 2020-06-07 -0.037037      0.098148
# 2020-06-08  0.007583      0.117127
# 2020-06-09  0.033414      0.132757
# 2020-06-10  0.032257      0.167842
# 2020-06-11  0.024103      0.107316
#
# [3745 rows x 2 columns]

# %%
publishers_names["publisher"].index.value_counts()
# Out:
# 2020-03-12 00:00:00    1469
# 2020-02-27 00:00:00    1241
# 2020-02-28 00:00:00    1191
# 2019-08-01 00:00:00    1172
# 2009-08-10 00:00:00    1129
#                        ...
# 2016-09-21 12:31:54       1
# 2020-04-23 20:22:22       1
# 2020-05-19 13:19:36       1
# 2020-05-27 09:59:25       1
# 2017-11-14 17:25:57       1
# Name: date, Length: 34974, dtype: int64
