# %%
import sys 
import pynance as py
sys.path.append(r'C:\Users\Baslael\Documents\Kifiya\week1\script')
from Stock_Analysis import Stocks

# %%
qnt=py.data.get('AAPL')
qnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35004/1617775129.py in <module>
# ----> 1 qnt=py.data.get('AAPL')
#       2 qnt
#
# NameError: name 'py' is not defined

# %%
#index to date
Stocks.index_edit(qnt,'Date')
qnt
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...                ...         ...         ...         ...         ...
# 2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
#                Volume  Dividends  Stock Splits
# Date
# 1980-12-12  469033600        0.0           0.0
# ...

# %%
import talib as ta
import pandas as pd

qnt['RSI']=ta.RSI(qnt['Close'],timeperiod=10)

# %%
# qnt['Signals']='Neutral'
qnt.loc[qnt['RSI']>70, 'Signals']='Buy'
qnt.loc[qnt['RSI']<30, 'Signals']='Sell'

# %%
qnt[qnt['Signals']=='Sell']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1981-02-02    0.119420    0.119420    0.118862    0.118862    0.091630
# 1981-02-12    0.117188    0.117188    0.116629    0.116629    0.089909
# 1981-02-13    0.114955    0.114955    0.113839    0.113839    0.087758
# 1981-02-20    0.108817    0.108817    0.108259    0.108259    0.083457
# 1981-02-24    0.107143    0.107143    0.106027    0.106027    0.081736
# ...                ...         ...         ...         ...         ...
# 2024-03-04  176.149994  176.899994  173.789993  175.100006  174.660660
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  169.693161
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  168.695648
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  168.575958
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.301605
#
#               Volume  Dividends  Stock Splits        RSI Signals
# Date
# ...

# %%
qnt['MACD']=ta.MACD(qnt['Close'], signalperiod=10)[1]
qnt.head(50)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.098943  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.093781  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.086898  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089049   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.091630   73449600
# 1980-12-19  0.126116  0.126674  0.126116  0.126116   0.097223   48630400
# 1980-12-22  0.132254  0.132813  0.132254  0.132254   0.101954   37363200
# 1980-12-23  0.137835  0.138393  0.137835  0.137835   0.106257   46950400
# 1980-12-24  0.145089  0.145647  0.145089  0.145089   0.111849   48003200
# 1980-12-26  0.158482  0.159040  0.158482  0.158482   0.122173   55574400
# 1980-12-29  0.160714  0.161272  0.160714  0.160714   0.123894   93161600
# 1980-12-30  0.157366  0.157366  0.156808  0.156808   0.120883   68880000
# ...

# %%
macd[1]
# Out:
# Date
# 1980-12-12         NaN
# 1980-12-15         NaN
# 1980-12-16         NaN
# 1980-12-17         NaN
# 1980-12-18         NaN
#                 ...
# 2024-07-24    6.766908
# 2024-07-25    6.218031
# 2024-07-26    5.637710
# 2024-07-29    5.057870
# 2024-07-30    4.504214
# Length: 10998, dtype: float64
