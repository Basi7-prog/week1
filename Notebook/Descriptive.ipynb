# %%
import sys 
sys.path.append(r'C:\Users\Baslael\Documents\Kifiya\week1\script')
from Stock_Analysis import Stocks

# %%
snt=Stocks.read_sentiment()
snt
# Out:
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %%
[wht,publishers_names]=Stocks.active_publisher(snt)
wht
# Out:
# C:\Users\Baslael\Documents\Kifiya\week1\script\Stock_Analysis.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snt2['date']=Stocks.change_to_date(snt2['date'])
#                    articles published  in_percent
# Paul Quintaro                  228373   16.227418
# Lisa Levin                     186979   13.286100
# Benzinga Newsdesk              150484   10.692888
# Charles Gross                   96732    6.873451
# Monica Gerson                   82380    5.853646
# Eddie Staley                    57254    4.068277
# Hal Lindon                      49047    3.485115
# ETF Professor                   28489    2.024333
# Juan Lopez                      28438    2.020709
# Benzinga Staff                  28114    1.997686
# ...

# %%
publishers_names
# Out:
#          Unnamed: 0                                           headline  \
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# 7                 7  Agilent Technologies shares are trading higher...
# 9                 9         10 Biggest Price Target Changes For Friday
# ...             ...                                                ...
# 1407320     1413841  China Zenix Announces Open Market Stock Purcha...
# 1407321     1413842  China Zenix Auto International Awarded Wheel S...
# 1407322     1413843  China Zenix Auto International Selected as Exc...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %%
Stocks.plot_news_frequency(publishers_names['date'],'W')
# Out:
# <AxesSubplot:>

# %%
from textblob import TextBlob

# %%
import pandas as pd
# blobs=pd.DataFrame()
# blobs['headline']=publishers_names["headline"].copy()
polarity=[]
subjectivity=[]
# positive=[]
# negative=[]
for index, row in publishers_names.iterrows():
    # print(row)
    polarity.append(TextBlob(row["headline"]).sentiment.polarity)
    subjectivity.append(TextBlob(row["headline"]).sentiment.subjectivity)
    
publishers_names["polarity"]=polarity
publishers_names["subjectivity"]=subjectivity

# %%
publishers_names[publishers_names["polarity"]<-0.5]
# Out:
#                                                   headline  polarity  \
# 812      Zacks #1 Rank Additions for Tuesday - Tale of ...    -0.800
# 813      Zacks #1 Rank Additions for Tuesday - Tale of ...    -0.800
# 814      Zacks #1 Rank Additions for Tuesday - Tale of ...    -0.800
# 815      Zacks #1 Rank Additions for Tuesday - Tale of ...    -0.800
# 1585     Mid-Day Market Update: Crude Oil Up Over 2%; N...    -0.700
# ...                                                    ...       ...
# 1404986  Jim Cramer Interviews CEO Andrew P. Mooney of ...    -0.625
# 1406048  Jim Cramer Interviews CEO Juan Ram Alaix of Zo...    -0.625
# 1406074  Cryoport, Zoetis Announce Expanded Relationshi...    -0.600
# 1406166      Worst Performing Industries For June 10, 2015    -1.000
# 1407238  Retailers Disappointed In April (COST, GPS, AN...    -0.750
#
#          subjectivity
# 812              0.90
# 813              0.90
# 814              0.90
# 815              0.90
# ...
