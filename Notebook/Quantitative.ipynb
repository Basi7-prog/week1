# %%
import sys 
import pynance as py
sys.path.append(r'C:\Users\Baslael\Documents\Kifiya\week1\script')
from Stock_Analysis import Stocks

# %%
qnt=py.data.get('AAPL')
qnt.sort_index()
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2019-09-04   50.8878   51.1559   50.6246   51.0832  7.869739e+07
# 2019-09-05   51.7691   52.2486   51.6484   52.0811  9.806852e+07
# 2019-09-06   52.2686   52.3583   51.8927   52.0751  7.929314e+07
# 2019-09-09   52.4610   52.8498   51.5388   52.2954  1.118384e+08
# 2019-09-10   52.2237   52.9336   51.6973   52.9136  1.301381e+08
# ...              ...       ...       ...       ...           ...
# 2024-08-26  226.7600  227.2800  223.8905  227.1800  3.060221e+07
# 2024-08-27  225.9950  228.8500  224.8900  228.0300  3.593456e+07
# 2024-08-28  227.9200  229.8600  225.6800  226.4900  3.805217e+07
# 2024-08-29  230.1000  232.9200  228.8800  229.7900  5.190630e+07
# 2024-08-30  230.1900  230.4000  227.4800  229.0000  5.299077e+07
#
# [1257 rows x 5 columns]

# %%
#index to date
# Stocks.index_edit(qnt,'Date')
# qnt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Baslael\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\Baslael\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Baslael\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22668/277854052.py in <module>
#       1 #index to date
# ----> 2 Stocks.index_edit(qnt,'Date')
#       3 qnt
#
# ~\Documents\Kifiya\week1\script\Stock_Analysis.py in index_edit(data, col)
#      43
#      44     def index_edit(data, col):
# ---> 45         data[col]=Stocks.change_to_date(data[col])
#      46         data.set_index(col,inplace=True)
#      47         data.index=pd.to_datetime(data.index)
#
# c:\Users\Baslael\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\Baslael\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Date'

# %%
import talib as ta
import pandas as pd

qnt['RSI']=ta.RSI(qnt['Close'],timeperiod=10)

# %%
qnt['Signals']='Neutral'
qnt.loc[qnt['RSI']>70, 'Signals']='Buy'
qnt.loc[qnt['RSI']<30, 'Signals']='Sell'

# %%
qnt[qnt['Signals']=='Sell']
# Out:
#                 Open      High       Low     Close        Volume        RSI  \
# Date
# 2024-08-14  220.5700  223.0300  219.7000  221.7200  4.196057e+07  26.184019
# 2024-08-13  219.0100  221.8900  219.0100  221.2700  4.415533e+07  25.270277
# 2024-08-12  216.0700  219.5099  215.6000  217.5300  3.802809e+07  19.111453
# 2024-08-09  212.1000  216.7800  211.9700  216.2400  4.220165e+07  17.478865
# 2024-08-08  213.1100  214.2000  208.8300  213.3100  4.716115e+07  14.378976
# ...              ...       ...       ...       ...           ...        ...
# 2019-10-02   54.4668   54.5954   53.2177   53.4649  1.464753e+08  16.843884
# 2019-09-27   53.8558   53.9594   53.0582   53.4331  1.038604e+08  26.878706
# 2019-09-26   53.7212   53.9544   53.4331   53.6932  7.817112e+07  29.814995
# 2019-09-24   53.9764   54.3243   53.0352   53.1578  1.287311e+08  28.783696
# 2019-09-04   50.8878   51.1559   50.6246   51.0832  7.869739e+07  26.383767
#
#            Signals
# Date
# 2024-08-14    Sell
# 2024-08-13    Sell
# 2024-08-12    Sell
# 2024-08-09    Sell
# 2024-08-08    Sell
# ...            ...
# 2019-10-02    Sell
# 2019-09-27    Sell
# 2019-09-26    Sell
# 2019-09-24    Sell
# 2019-09-04    Sell
#
# [239 rows x 7 columns]

# %%
qnt['MACD_line'],qnt['MACD_sginal'],qnt['MACD_hist']=ta.MACD(qnt['Close'], signalperiod=10)
qnt
# Out:
#                 Open      High       Low     Close        Volume        RSI  \
# Date
# 2024-08-30  230.1900  230.4000  227.4800  229.0000  5.299077e+07        NaN
# 2024-08-29  230.1000  232.9200  228.8800  229.7900  5.190630e+07        NaN
# 2024-08-28  227.9200  229.8600  225.6800  226.4900  3.805217e+07        NaN
# 2024-08-27  225.9950  228.8500  224.8900  228.0300  3.593456e+07        NaN
# 2024-08-26  226.7600  227.2800  223.8905  227.1800  3.060221e+07        NaN
# ...              ...       ...       ...       ...           ...        ...
# 2019-09-10   52.2237   52.9336   51.6973   52.9136  1.301381e+08  36.679940
# 2019-09-09   52.4610   52.8498   51.5388   52.2954  1.118384e+08  33.071649
# 2019-09-06   52.2686   52.3583   51.8927   52.0751  7.929314e+07  31.831777
# 2019-09-05   51.7691   52.2486   51.6484   52.0811  9.806852e+07  31.909028
# 2019-09-04   50.8878   51.1559   50.6246   51.0832  7.869739e+07  26.383767
#
#             Signals  MACD_line  MACD_sginal  MACD_hist
# Date
# 2024-08-30  Neutral        NaN          NaN        NaN
# 2024-08-29  Neutral        NaN          NaN        NaN
# 2024-08-28  Neutral        NaN          NaN        NaN
# 2024-08-27  Neutral        NaN          NaN        NaN
# 2024-08-26  Neutral        NaN          NaN        NaN
# ...             ...        ...          ...        ...
# 2019-09-10  Neutral  -1.128465    -1.447196   0.318731
# 2019-09-09  Neutral  -1.177241    -1.398114   0.220873
# 2019-09-06  Neutral  -1.219614    -1.365659   0.146045
# 2019-09-05  Neutral  -1.238435    -1.342527   0.104093
# 2019-09-04     Sell  -1.318672    -1.338190   0.019518
#
# [1257 rows x 10 columns]

# %%
qnt.isna().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# RSI            10
# Signals         0
# MACD_line      34
# MACD_sginal    34
# MACD_hist      34
# dtype: int64

# %%
rsi_mean,macd_mean=qnt['RSI'].mean(),qnt['MACD_line'].mean()
rsi_mean,macd_mean
# Out:
# (44.29603651035499, -0.9593862585042494)

# %%
#filled the nan to mean of each column
qnt.loc[qnt['RSI'].isna(),'RSI']=rsi_mean
qnt.loc[qnt['MACD_line'].isna(),'MACD_line']=macd_mean

qnt
# Out:
#                 Open      High       Low     Close        Volume        RSI  \
# Date
# 2024-08-30  230.1900  230.4000  227.4800  229.0000  5.299077e+07  44.296037
# 2024-08-29  230.1000  232.9200  228.8800  229.7900  5.190630e+07  44.296037
# 2024-08-28  227.9200  229.8600  225.6800  226.4900  3.805217e+07  44.296037
# 2024-08-27  225.9950  228.8500  224.8900  228.0300  3.593456e+07  44.296037
# 2024-08-26  226.7600  227.2800  223.8905  227.1800  3.060221e+07  44.296037
# ...              ...       ...       ...       ...           ...        ...
# 2019-09-10   52.2237   52.9336   51.6973   52.9136  1.301381e+08  36.679940
# 2019-09-09   52.4610   52.8498   51.5388   52.2954  1.118384e+08  33.071649
# 2019-09-06   52.2686   52.3583   51.8927   52.0751  7.929314e+07  31.831777
# 2019-09-05   51.7691   52.2486   51.6484   52.0811  9.806852e+07  31.909028
# 2019-09-04   50.8878   51.1559   50.6246   51.0832  7.869739e+07  26.383767
#
#             Signals  MACD_line  MACD_sginal  MACD_hist
# Date
# 2024-08-30  Neutral  -0.959386          NaN        NaN
# 2024-08-29  Neutral  -0.959386          NaN        NaN
# 2024-08-28  Neutral  -0.959386          NaN        NaN
# 2024-08-27  Neutral  -0.959386          NaN        NaN
# 2024-08-26  Neutral  -0.959386          NaN        NaN
# ...             ...        ...          ...        ...
# 2019-09-10  Neutral  -1.128465    -1.447196   0.318731
# 2019-09-09  Neutral  -1.177241    -1.398114   0.220873
# 2019-09-06  Neutral  -1.219614    -1.365659   0.146045
# 2019-09-05  Neutral  -1.238435    -1.342527   0.104093
# 2019-09-04     Sell  -1.318672    -1.338190   0.019518
#
# [1257 rows x 10 columns]

# %%
qnt.sort_index()
# Out:
#                 Open      High       Low     Close        Volume        RSI  \
# Date
# 2019-09-04   50.8878   51.1559   50.6246   51.0832  7.869739e+07  26.383767
# 2019-09-05   51.7691   52.2486   51.6484   52.0811  9.806852e+07  31.909028
# 2019-09-06   52.2686   52.3583   51.8927   52.0751  7.929314e+07  31.831777
# 2019-09-09   52.4610   52.8498   51.5388   52.2954  1.118384e+08  33.071649
# 2019-09-10   52.2237   52.9336   51.6973   52.9136  1.301381e+08  36.679940
# ...              ...       ...       ...       ...           ...        ...
# 2024-08-26  226.7600  227.2800  223.8905  227.1800  3.060221e+07  44.296037
# 2024-08-27  225.9950  228.8500  224.8900  228.0300  3.593456e+07  44.296037
# 2024-08-28  227.9200  229.8600  225.6800  226.4900  3.805217e+07  44.296037
# 2024-08-29  230.1000  232.9200  228.8800  229.7900  5.190630e+07  44.296037
# 2024-08-30  230.1900  230.4000  227.4800  229.0000  5.299077e+07  44.296037
#
#             Signals  MACD_line  MACD_sginal  MACD_hist
# Date
# 2019-09-04     Sell  -1.318672    -1.338190   0.019518
# 2019-09-05  Neutral  -1.238435    -1.342527   0.104093
# 2019-09-06  Neutral  -1.219614    -1.365659   0.146045
# 2019-09-09  Neutral  -1.177241    -1.398114   0.220873
# 2019-09-10  Neutral  -1.128465    -1.447196   0.318731
# ...             ...        ...          ...        ...
# 2024-08-26  Neutral  -0.959386          NaN        NaN
# 2024-08-27  Neutral  -0.959386          NaN        NaN
# 2024-08-28  Neutral  -0.959386          NaN        NaN
# 2024-08-29  Neutral  -0.959386          NaN        NaN
# 2024-08-30  Neutral  -0.959386          NaN        NaN
#
# [1257 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

data_size=100
fig,ax=plt.subplots(4,1,figsize=(20,20))

ax[1].plot(qnt['RSI'].head(data_size))
ax[1].set_title('RSI')
ax[2].plot(qnt['MACD_line'].head(data_size))
ax[2].plot(qnt['MACD_sginal'].head(data_size))
ax[2].set_title('MACD_sginal and MACD_line')
ax[2].legend(loc='upper left', fontsize=12)
ax[3].plot(qnt['MACD_hist'].head(data_size))
ax[3].set_title('MACD_hist')
ax[0].plot(qnt['Close'].head(data_size))
ax[0].set_title('Close')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Close')
